# %% [markdown]
# # Trying out features

# %% [markdown]
# **Learning Objectives:**
#   * Improve the accuracy of a model by adding new features with the appropriate representation

# %% [markdown]
# The data is based on 1990 census data from California. This data is at the city block level, so these features reflect the total number of rooms in that block, or the total number of people who live on that block, respectively.

# %% [markdown]
# ## Set Up
# In this first cell, we'll load the necessary libraries.

# %%
import math
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf

print(tf.__version__)
tf.logging.set_verbosity(tf.logging.INFO)
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:.1f}'.format
# Out:
# 1.14.0

# %% [markdown]
# Next, we'll load our data set.

# %%
df = pd.read_csv("https://storage.googleapis.com/ml_universities/california_housing_train.csv", sep=",")

# %% [markdown]
# ## Examine and split the data
#
# It's a good idea to get to know your data a little bit before you work with it.
#
# We'll print out a quick summary of a few useful statistics on each column.
#
# This will include things like mean, standard deviation, max, min, and various quantiles.

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0            1.5             66900.0
# 1      1129.0       463.0            1.8             80100.0
# 2       333.0       117.0            1.7             85700.0
# 3       515.0       226.0            3.2             73400.0
# 4       624.0       262.0            1.9             65500.0

# %%
df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9            207300.9
# std        1147.9       384.5            1.9            115983.8
# min           3.0         1.0            0.5             14999.0
# 25%         790.0       282.0            2.6            119400.0
# 50%        1167.0       409.0            3.5            180400.0
# 75%        1721.0       605.2            4.8            265000.0
# max       35682.0      6082.0           15.0            500001.0

# %% [markdown]
# Now, split the data into two parts -- training and evaluation.

# %%
#np.random.seed(seed=1) #makes result reproducible
msk = np.random.rand(len(df)) < 0.8
traindf = df[msk]
evaldf = df[~msk]

# %% [markdown]
# ## Training and Evaluation
#
# In this exercise, we'll be trying to predict **median_house_value** It will be our label (sometimes also called a target).
#
# We'll modify the feature_cols and input function to represent the features you want to use.
#
# We divide **total_rooms** by **households** to get **avg_rooms_per_house** which we expect to positively correlate with **median_house_value**.
#
# We also divide **population** by **total_rooms** to get **avg_persons_per_room** which we expect to negatively correlate with **median_house_value**.

# %%
def add_more_features(df):
    df['avg_rooms_per_house'] = df['total_rooms'] / df['households'] #expect positive correlation
    df['avg_persons_per_room'] = df['population'] / df['total_rooms'] #expect negative correlation
    return df

# %%
# Create pandas input function
def make_input_fn(df, num_epochs):
      return tf.estimator.inputs.pandas_input_fn(
            x = add_more_features(df),
            y = df['median_house_value'] / 100000, # will talk about why later in the course
            batch_size = 128,
            num_epochs = num_epochs,
            shuffle = True,
            queue_capacity = 1000,
            num_threads = 1
      )

# %%
# Define your feature columns
def create_feature_cols():
      return [
            tf.feature_column.numeric_column('housing_median_age'),
            tf.feature_column.bucketized_column(tf.feature_column.numeric_column('latitude'), boundaries = np.arange(32.0, 42, 1).tolist()),
            tf.feature_column.bucketized_column(tf.feature_column.numeric_column('longitude'), boundaries = np.arange(-124, -114, 1).tolist()),
            tf.feature_column.numeric_column('avg_rooms_per_house'),
            tf.feature_column.numeric_column('avg_persons_per_room'),
            tf.feature_column.numeric_column('median_income')
      ]

# %%
# Create estimator train and evaluate function
def train_and_evaluate(output_dir, num_train_steps):
        estimator = tf.estimator.LinearRegressor(model_dir = output_dir, 
                                               feature_columns = create_feature_cols())
        train_spec = tf.estimator.TrainSpec(input_fn = make_input_fn(traindf, None), 
                                          max_steps = num_train_steps)
        eval_spec = tf.estimator.EvalSpec(input_fn = make_input_fn(evaldf, 1), 
                                        steps = None, 
                                        start_delay_secs = 1, # start evaluating after N seconds, 
                                        throttle_secs = 10)  # evaluate every N seconds
        tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# %%
# Launch tensorboard
OUTDIR = './trained_model'

# %%
# Run the model
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time
#tf.summary.FileWriterCache.clear() # ensure filewriter cache is clear for TensorBoard events file
train_and_evaluate(OUTDIR, 2000)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_num_worker_replicas': 1, '_keep_checkpoint_max': 5, '_eval_distribute': None, '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f4a0ece5780>, '_keep_checkpoint_every_n_hours': 10000, '_device_fn': None, '_task_id': 0, '_num_ps_replicas': 0, '_service': None, '_master': '', '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_task_type': 'worker', '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_protocol': None, '_is_chief': True, '_save_summary_steps': 100, '_tf_random_seed': None, '_experimental_max_worker_delay_secs': None, '_global_id_in_cluster': 0, '_train_distribute': None, '_experimental_distribute': None, '_model_dir': './trained_model', '_save_checkpoints_secs': 600}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_model/model.ckpt.
# INFO:tensorflow:loss = 330.98032, step = 1
# INFO:tensorflow:global_step/sec: 68.7895
# INFO:tensorflow:loss = 88.96111, step = 101 (1.460 sec)
# INFO:tensorflow:global_step/sec: 58.6605
# INFO:tensorflow:loss = 167.14285, step = 201 (1.701 sec)
# INFO:tensorflow:global_step/sec: 89.8141
# INFO:tensorflow:loss = 56.178524, step = 301 (1.112 sec)
# INFO:tensorflow:global_step/sec: 97.3007
# INFO:tensorflow:loss = 53.300964, step = 401 (1.028 sec)
# INFO:tensorflow:global_step/sec: 92.2705
# INFO:tensorflow:loss = 49.112724, step = 501 (1.084 sec)
# INFO:tensorflow:global_step/sec: 99.5947
# INFO:tensorflow:loss = 52.33559, step = 601 (1.004 sec)
# INFO:tensorflow:global_step/sec: 84.3924
# INFO:tensorflow:loss = 80.14741, step = 701 (1.190 sec)
# INFO:tensorflow:global_step/sec: 107.296
# INFO:tensorflow:loss = 82.84185, step = 801 (0.933 sec)
# INFO:tensorflow:global_step/sec: 89.016
# INFO:tensorflow:loss = 104.96895, step = 901 (1.122 sec)
# INFO:tensorflow:global_step/sec: 103.094
# INFO:tensorflow:loss = 115.100945, step = 1001 (0.971 sec)
# INFO:tensorflow:global_step/sec: 99.8626
# INFO:tensorflow:loss = 91.68121, step = 1101 (1.001 sec)
# INFO:tensorflow:global_step/sec: 97.7073
# INFO:tensorflow:loss = 76.01808, step = 1201 (1.024 sec)
# INFO:tensorflow:global_step/sec: 87.6655
# INFO:tensorflow:loss = 90.75061, step = 1301 (1.140 sec)
# INFO:tensorflow:global_step/sec: 97.2591
# INFO:tensorflow:loss = 64.556625, step = 1401 (1.029 sec)
# INFO:tensorflow:global_step/sec: 85.6868
# INFO:tensorflow:loss = 66.12307, step = 1501 (1.167 sec)
